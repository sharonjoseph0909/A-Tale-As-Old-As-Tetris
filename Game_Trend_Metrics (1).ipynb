# %%
import kagglehub

path = kagglehub.dataset_download("gabrigoncam/video-game-dataset-multidimensional")
print("Path to dataset files:", path)

import pandas as pd
df = pd.read_csv(path + "/game_developers.csv")
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import kagglehub
#       3 path = kagglehub.dataset_download("gabrigoncam/video-game-dataset-multidimensional")
#       4 print("Path to dataset files:", path)
#
# ModuleNotFoundError: No module named 'kagglehub'
